# %%
# Dependencies for pandas table extraction
import pandas as pd

# %%
file_path = "Resources/occ-15-1111.xlsx"
outlook_df = pd.read_excel(file_path)

# %%
outlook_df.head()
# Out:
#   Employment by industry, occupation, and percent distribution, 2016 and projected 2026  \
# 0  15-1111 Computer and information research scie...
# 1  (Employment in thousands)\nIndustries with few...
# 2                                                NaN
# 3                                         Sort Order
# 4                                                  1
#
#   Unnamed: 1        Unnamed: 2  Unnamed: 3           Unnamed: 4  \
# 0        NaN               NaN         NaN                  NaN
# 1        NaN               NaN         NaN                  NaN
# 2   Industry               NaN        2016                  NaN
# 3       Code             Title  Employment  Percent of industry
# 4     TE1000  Total employment        27.9                    0
#
#               Unnamed: 5  Unnamed: 6           Unnamed: 7  \
# 0                    NaN         NaN                  NaN
# 1                    NaN         NaN                  NaN
# ...
